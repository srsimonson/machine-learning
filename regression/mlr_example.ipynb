# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Make synthetic data for testing
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1': X[:,0], 'feature2':X[:,1], 'target':'y'})

# %%
df.head()
# Out:
#    feature1  feature2 target
# 0  0.936461  0.975931      y
# 1 -0.418471  1.506944      y
# 2  0.720145 -0.461815      y
# 3 -1.929335  0.429347      y
# 4 -1.825024 -0.497292      y

# %%
df.shape
# Out:
# (100, 3)

# %%
# Create a scatter plot
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.show()

# %%
# %pip install -U jupyterlab
# %pip install -U nbformat
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a scatter plot
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.update_traces(marker=dict(size=3))   # default is usually ~5–8
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
len(X_train)
# Out:
# 80

# %%
len(X_test)
# Out:
# 20

# %% [markdown]
# ## Build Model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction data
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([  71.35546123,  168.88922859,   64.54074151,  -32.98211122,
#        -156.01806214, -132.20777461,   14.77564638,   -2.43496344,
#          96.98514432,  -58.70572895,    1.11636799,  119.68680165,
#         -18.68968074, -137.20767353,  -31.10209094, -159.63536079,
#         179.06380286, -119.35421533,   37.66218124,  198.09080421])

# %%
# Test data
y_test
# Out:
# array([ 3.24934106e-02,  1.30720389e+02,  4.04372123e+01, -2.16046430e+01,
#        -1.50881142e+02, -7.87574968e+01,  7.09863405e+01, -7.45715608e+01,
#         1.33130716e+01, -1.62640165e+02, -1.79724190e+00,  8.36536899e+01,
#        -2.24689232e+01, -1.92674294e+02,  1.82390476e+01, -1.98504867e+02,
#         1.63224277e+02,  1.58084512e+01,  7.84321628e+01,  2.20037705e+02])

# %%
# Validate... 
# However, the numbers are somewhat meaningless until you create several iterations of several models
# to compare the scores against each other over time.
print('MAE: ', mean_absolute_error(y_test,y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R2-score: ', r2_score(y_test, y_pred))
# Out:
# MAE:  45.981805330611756
# MSE:  3265.553544715571
# RMSE:  57.145022046680246
# R2-score:  0.7397706246675619
